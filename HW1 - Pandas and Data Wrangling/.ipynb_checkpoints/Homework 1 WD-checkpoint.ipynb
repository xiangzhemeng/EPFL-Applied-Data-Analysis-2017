# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Task-1.-Compiling-Ebola-Data"><span class="toc-item-num">Task 1.&nbsp;&nbsp;</span>Compiling Ebola Data</a></div>
#  <div class="lev1"><a href="#Task-2.-RNA-Sequences"><span class="toc-item-num">Task 2.&nbsp;&nbsp;</span>RNA Sequences</a></div>
#  <div class="lev1"><a href="#Task-3.-Class-War-in-Titanic"><span class="toc-item-num">Task 3.&nbsp;&nbsp;</span>Class War in Titanic</a></div></p>

# %%
DATA_FOLDER = 'Data' # Use the data folder provided in Tutorial 02 - Intro to Pandas.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('notebook')

# %% [markdown]
# ## Task 1. Compiling Ebola Data
#
# The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country.
#
# Use pandas to import these data files into a single `Dataframe`.
# Using this `DataFrame`, calculate for *each country*, the *daily average per month* of *new cases* and *deaths*.
# Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports.

# %%
# Write your answer here

# %% [markdown]
# ## Task 2. RNA Sequences
#
# In the `DATA_FOLDER/microbiome` subdirectory, there are 9 spreadsheets of microbiome data that was acquired from high-throughput RNA sequencing procedures, along with a 10<sup>th</sup> file that describes the content of each.
#
# Use pandas to import the first 9 spreadsheets into a single `DataFrame`.
# Then, add the metadata information from the 10<sup>th</sup> spreadsheet as columns in the combined `DataFrame`.
# Make sure that the final `DataFrame` has a unique index and all the `NaN` values have been replaced by the tag `unknown`.

# %%
import pandas as pd
import numpy as np

# %%
mb=pd.read_excel('Data/microbiome/MID2.xls')
mb.head
# Out:
# <bound method NDFrame.head of     Archaea "Crenarchaeota" Thermoprotei Acidilobales Acidilobaceae Acidilobus  \
# 0    Archaea "Crenarchaeota" Thermoprotei Acidiloba...
# 1    Archaea "Crenarchaeota" Thermoprotei Desulfuro...
# 2    Archaea "Crenarchaeota" Thermoprotei Desulfuro...
# 3    Archaea "Crenarchaeota" Thermoprotei Desulfuro...
# 4    Archaea "Crenarchaeota" Thermoprotei Desulfuro...
# 5    Archaea "Crenarchaeota" Thermoprotei Desulfuro...
# 6    Archaea "Crenarchaeota" Thermoprotei Sulfoloba...
# 7    Archaea "Crenarchaeota" Thermoprotei Sulfoloba...
# 8    Archaea "Crenarchaeota" Thermoprotei Thermopro...
# 9    Archaea "Crenarchaeota" Thermoprotei Thermopro...
# 10   Archaea "Crenarchaeota" Thermoprotei Thermopro...
# 11   Archaea "Euryarchaeota" "Methanomicrobia" Meth...
# 12   Archaea "Euryarchaeota" "Methanomicrobia" Meth...
# 13   Archaea "Euryarchaeota" "Methanomicrobia" Meth...
# 14   Archaea "Euryarchaeota" "Methanomicrobia" Meth...
# 15   Archaea "Euryarchaeota" Archaeoglobi Archaeogl...
# 16   Archaea "Euryarchaeota" Halobacteria Halobacte...
# 17   Archaea "Euryarchaeota" Halobacteria Halobacte...
# 18   Archaea "Euryarchaeota" Halobacteria Halobacte...
# 19   Archaea "Euryarchaeota" Halobacteria Halobacte...
# 20   Archaea "Euryarchaeota" Halobacteria Halobacte...
# 21   Archaea "Euryarchaeota" Halobacteria Halobacte...
# 22   Archaea "Euryarchaeota" Halobacteria Halobacte...
# 23   Archaea "Euryarchaeota" Methanobacteria Methan...
# 24   Archaea "Euryarchaeota" Methanopyri Methanopyr...
# 25   Archaea "Euryarchaeota" Thermoplasmata Thermop...
# 26   Bacteria "Acidobacteria" Holophagae Holophagal...
# 27   Bacteria "Actinobacteria" Actinobacteria Actin...
# 28   Bacteria "Actinobacteria" Actinobacteria Actin...
# 29   Bacteria "Actinobacteria" Actinobacteria Actin...
# ..                                                 ...
# 257  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 258  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 259  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 260  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 261  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 262  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 263  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 264  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 265  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 266  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 267  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 268  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 269  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 270  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 271  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 272  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 273  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 274  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 275  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 276  Bacteria "Proteobacteria" Gammaproteobacteria ...
# 277  Bacteria "Synergistetes" Synergistia Synergist...
# 278  Bacteria "Synergistetes" Synergistia Synergist...
# 279  Bacteria "Tenericutes" Mollicutes Haloplasmata...
# 280  Bacteria "Thermodesulfobacteria" Thermodesulfo...
# 281  Bacteria "Thermodesulfobacteria" Thermodesulfo...
# 282  Bacteria "Thermotogae" Thermotogae Thermotogal...
# 283  Bacteria "Thermotogae" Thermotogae Thermotogal...
# 284  Bacteria Cyanobacteria Cyanobacteria  Chloropl...
# 285  Bacteria Cyanobacteria Cyanobacteria  Chloropl...
# 286          Bacteria TM7    TM7_genera_incertae_sedis
#
#       2
# 0    14
# 1    23
# 2     1
# 3     2
# 4     1
# 5     2
# 6    10
# 7    11
# 8     9
# 9     5
# 10    3
# 11    9
# 12    1
# 13   12
# 14    2
# 15    4
# 16    3
# 17    1
# 18    4
# 19    3
# 20    5
# 21    2
# 22   26
# 23    1
# 24   47
# 25   10
# 26    1
# 27    1
# 28    4
# 29    1
# ..   ..
# 257  48
# 258   3
# 259   1
# 260   3
# 261   1
# 262   2
# 263   3
# 264   3
# 265   1
# 266   1
# 267   3
# 268   1
# 269   9
# 270  10
# 271  40
# 272   9
# 273   1
# 274   1
# 275   2
# 276   3
# 277   2
# 278   2
# 279  15
# 280   1
# 281   3
# 282  15
# 283  22
# 284   1
# 285   2
# 286   2
#
# [287 rows x 2 columns]>

# %% [markdown]
# ## Task 3. Class War in Titanic
#
# Use pandas to import the data file `Data/titanic.xls`. It contains data on all the passengers that travelled on the Titanic.

# %%
from IPython.core.display import HTML
HTML(filename=DATA_FOLDER+'/titanic.html')
# Out:
# <hr><h2>Data frame:titanic3</h2>1309 observations and 14 variables, maximum # NAs:1188<hr>
# <TABLE BORDER>
# <tr><td>Name</td><td>Labels</td><td>Units</td><td>Levels</td><td>Storage</td><td>NAs</td></tr>
# <tr><td>pclass</td><td></td><td></td><td><a href="#pclass"><div align=right>  3</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>survived</td><td>Survived</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>name</td><td>Name</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# <tr><td>sex</td><td></td><td></td><td><a href="#sex"><div align=right>  2</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>age</td><td>Age</td><td>Year</td><td><div align=right></div></td><td>double</td><td><div align=right> 263</div></td></tr>
# <tr><td>sibsp</td><td>Number of Siblings/Spouses Aboard</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>parch</td><td>Number of Parents/Children Aboard</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>ticket</td><td>Ticket Number</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# <tr><td>fare</td><td>Passenger Fare</td><td>British Pound (\243)</td><td><div align=right></div></td><td>double</td><td><div align=right>   1</div></td></tr>
# <tr><td>cabin</td><td></td><td></td><td><a href="#cabin"><div align=right>187</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>embarked</td><td></td><td></td><td><a href="#embarked"><div align=right>  3</div></a></td><td>integer</td><td><div align=right>   2</div></td></tr>
# <tr><td>boat</td><td></td><td></td><td><a href="#boat"><div align=right> 28</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>body</td><td>Body Identification Number</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>1188</div></td></tr>
# <tr><td>home.dest</td><td>Home/Destination</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# </TABLE>
# <hr>
# <TABLE BORDER>
# <tr><td>Variable</td><td>Levels</td></tr>
# <tr><td><a name="pclass">pclass</a></td><td>1st</td></tr>
# <tr><td></td><td>2nd</td></tr>
# <tr><td></td><td>3rd</td></tr>
# <tr><td><a name="sex">sex</a></td><td>female</td></tr>
# <tr><td></td><td>male</td></tr>
# <tr><td><a name="cabin">cabin</a></td><td></td></tr>
# <tr><td></td><td>A10</td></tr>
# <tr><td></td><td>A11</td></tr>
# <tr><td></td><td>A14</td></tr>
# <tr><td></td><td>A16</td></tr>
# <tr><td></td><td>A18</td></tr>
# <tr><td></td><td>A19</td></tr>
# <tr><td></td><td>A20</td></tr>
# <tr><td></td><td>A21</td></tr>
# <tr><td></td><td>A23</td></tr>
# <tr><td></td><td>A24</td></tr>
# <tr><td></td><td>A26</td></tr>
# <tr><td></td><td>A29</td></tr>
# <tr><td></td><td>A31</td></tr>
# <tr><td></td><td>A32</td></tr>
# <tr><td></td><td>A34</td></tr>
# <tr><td></td><td>A36</td></tr>
# <tr><td></td><td>A5</td></tr>
# <tr><td></td><td>A6</td></tr>
# <tr><td></td><td>A7</td></tr>
# <tr><td></td><td>A9</td></tr>
# <tr><td></td><td>B10</td></tr>
# <tr><td></td><td>B101</td></tr>
# <tr><td></td><td>B102</td></tr>
# <tr><td></td><td>B11</td></tr>
# 2. Plot histograms for the *travel class*, *embarkation port*, *sex* and *age* attributes. For the latter one, use *discrete decade intervals*.
# 3. Calculate the proportion of passengers by *cabin floor*. Present your results in a *pie chart*.
# 4. For each *travel class*, calculate the proportion of the passengers that survived. Present your results in *pie charts*.
# 5. Calculate the proportion of the passengers that survived by *travel class* and *sex*. Present your results in *a single histogram*.
# 6. Create 2 equally populated *age categories* and calculate survival proportions by *age category*, *travel class* and *sex*. Present your results in a `DataFrame` with unique index.

# %%
titanic=pd.read_excel(DATA_FOLDER+'/titanic.xls')
titanic.head(500)
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 1         1         1                     Allison, Master. Hudson Trevor
# 2         1         0                       Allison, Miss. Helen Loraine
# 3         1         0               Allison, Mr. Hudson Joshua Creighton
# 4         1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5         1         1                                Anderson, Mr. Harry
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 7         1         0                             Andrews, Mr. Thomas Jr
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9         1         0                            Artagaveytia, Mr. Ramon
# 10        1         0                             Astor, Col. John Jacob
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart, Mme. Leontine Pauline
# 13        1         1                       Barber, Miss. Ellen "Nellie"
# 14        1         1               Barkworth, Mr. Algernon Henry Wilson
# 15        1         0                                Baumann, Mr. John D
# 16        1         0                           Baxter, Mr. Quigg Edmond
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18        1         1                              Bazzani, Miss. Albina
# 19        1         0                               Beattie, Mr. Thomson
# 20        1         1                      Beckwith, Mr. Richard Leonard
# 21        1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22        1         1                              Behr, Mr. Karl Howell
# 23        1         1                              Bidois, Miss. Rosalie
# 24        1         1                                  Bird, Miss. Ellen
# 25        1         0                                Birnbaum, Mr. Jakob
# 26        1         1                            Bishop, Mr. Dickinson H
# 27        1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28        1         1                             Bissette, Miss. Amelia
# 29        1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# ..      ...       ...                                                ...
# 470       2         0                                  Keane, Mr. Daniel
# 471       2         1                      Kelly, Mrs. Florence "Fannie"
# 472       2         0                     Kirkland, Rev. Charles Leonard
# 473       2         0                               Knight, Mr. Robert J
# 474       2         0             Kvillner, Mr. Johan Henrik Johannesson
# 475       2         0              Lahtinen, Mrs. William (Anna Sylfven)
# 476       2         0                             Lahtinen, Rev. William
# 477       2         0                              Lamb, Mr. John Joseph
# 478       2         1                              Laroche, Miss. Louise
# 479       2         1           Laroche, Miss. Simonne Marie Anne Andree
# 480       2         0             Laroche, Mr. Joseph Philippe Lemercier
# 481       2         1  Laroche, Mrs. Joseph (Juliette Marie Louise La...
# 482       2         1                              Lehmann, Miss. Bertha
# 483       2         1                         Leitch, Miss. Jessie Wills
# 484       2         1                       Lemore, Mrs. (Amelia Milley)
# 485       2         0                             Levy, Mr. Rene Jacques
# 486       2         0                  Leyson, Mr. Robert William Norman
# 487       2         0                                  Lingane, Mr. John
# 488       2         0                       Louch, Mr. Charles Alexander
# 489       2         1  Louch, Mrs. Charles Alexander (Alice Adelaide ...
# 490       2         0                                  Mack, Mrs. (Mary)
# 491       2         0                                Malachard, Mr. Noel
# 492       2         1                              Mallet, Master. Andre
# 493       2         0                                 Mallet, Mr. Albert
# 494       2         1            Mallet, Mrs. Albert (Antoinette Magnin)
# 495       2         0                  Mangiavacchi, Mr. Serafino Emilio
# 496       2         0                         Matthews, Mr. William John
# 497       2         0                          Maybery, Mr. Frank Hubert
# 498       2         0                          McCrae, Mr. Arthur Gordon
# 499       2         0                          McCrie, Mr. James Matthew
#
#         sex      age  sibsp  parch           ticket      fare    cabin  \
# 0    female  29.0000      0      0            24160  211.3375       B5
# 1      male   0.9167      1      2           113781  151.5500  C22 C26
# 2    female   2.0000      1      2           113781  151.5500  C22 C26
# 3      male  30.0000      1      2           113781  151.5500  C22 C26
# 4    female  25.0000      1      2           113781  151.5500  C22 C26
# 5      male  48.0000      0      0            19952   26.5500      E12
# 6    female  63.0000      1      0            13502   77.9583       D7
# 7      male  39.0000      0      0           112050    0.0000      A36
# 8    female  53.0000      2      0            11769   51.4792     C101
# 9      male  71.0000      0      0         PC 17609   49.5042      NaN
# 10     male  47.0000      1      0         PC 17757  227.5250  C62 C64
# 11   female  18.0000      1      0         PC 17757  227.5250  C62 C64
# 12   female  24.0000      0      0         PC 17477   69.3000      B35
# 13   female  26.0000      0      0            19877   78.8500      NaN
# 14     male  80.0000      0      0            27042   30.0000      A23
# 15     male      NaN      0      0         PC 17318   25.9250      NaN
# 16     male  24.0000      0      1         PC 17558  247.5208  B58 B60
# 17   female  50.0000      0      1         PC 17558  247.5208  B58 B60
# 18   female  32.0000      0      0            11813   76.2917      D15
# 19     male  36.0000      0      0            13050   75.2417       C6
# 20     male  37.0000      1      1            11751   52.5542      D35
# 21   female  47.0000      1      1            11751   52.5542      D35
# 22     male  26.0000      0      0           111369   30.0000     C148
# 23   female  42.0000      0      0         PC 17757  227.5250      NaN
# 24   female  29.0000      0      0         PC 17483  221.7792      C97
# 25     male  25.0000      0      0            13905   26.0000      NaN
# 26     male  25.0000      1      0            11967   91.0792      B49
# 27   female  19.0000      1      0            11967   91.0792      B49
# 28   female  35.0000      0      0         PC 17760  135.6333      C99
# 29     male  28.0000      0      0           110564   26.5500      C52
# ..      ...      ...    ...    ...              ...       ...      ...
# 470    male  35.0000      0      0           233734   12.3500      NaN
# 471  female  45.0000      0      0           223596   13.5000      NaN
# 472    male  57.0000      0      0           219533   12.3500      NaN
# 473    male      NaN      0      0           239855    0.0000      NaN
# 474    male  31.0000      0      0       C.A. 18723   10.5000      NaN
# 475  female  26.0000      1      1           250651   26.0000      NaN
# 476    male  30.0000      1      1           250651   26.0000      NaN
# 477    male      NaN      0      0           240261   10.7083      NaN
# 478  female   1.0000      1      2    SC/Paris 2123   41.5792      NaN
# 479  female   3.0000      1      2    SC/Paris 2123   41.5792      NaN
# 480    male  25.0000      1      2    SC/Paris 2123   41.5792      NaN
# 481  female  22.0000      1      2    SC/Paris 2123   41.5792      NaN
# 482  female  17.0000      0      0          SC 1748   12.0000      NaN
# 483  female      NaN      0      0           248727   33.0000      NaN
# 484  female  34.0000      0      0       C.A. 34260   10.5000      F33
# 485    male  36.0000      0      0    SC/Paris 2163   12.8750        D
# 486    male  24.0000      0      0       C.A. 29566   10.5000      NaN
# 487    male  61.0000      0      0           235509   12.3500      NaN
# 488    male  50.0000      1      0       SC/AH 3085   26.0000      NaN
# 489  female  42.0000      1      0       SC/AH 3085   26.0000      NaN
# 490  female  57.0000      0      0      S.O./P.P. 3   10.5000      E77
# 491    male      NaN      0      0           237735   15.0458        D
# 492    male   1.0000      0      2  S.C./PARIS 2079   37.0042      NaN
# 493    male  31.0000      1      1  S.C./PARIS 2079   37.0042      NaN
# 494  female  24.0000      1      1  S.C./PARIS 2079   37.0042      NaN
# 495    male      NaN      0      0      SC/A.3 2861   15.5792      NaN
# 496    male  30.0000      0      0            28228   13.0000      NaN
# 497    male  40.0000      0      0           239059   16.0000      NaN
# 498    male  32.0000      0      0           237216   13.5000      NaN
# 499    male  30.0000      0      0           233478   13.0000      NaN
#
#     embarked boat   body                              home.dest
# 0          S    2    NaN                           St Louis, MO
# 1          S   11    NaN        Montreal, PQ / Chesterville, ON
# 2          S  NaN    NaN        Montreal, PQ / Chesterville, ON
# 3          S  NaN  135.0        Montreal, PQ / Chesterville, ON
# 4          S  NaN    NaN        Montreal, PQ / Chesterville, ON
# 5          S    3    NaN                           New York, NY
# 6          S   10    NaN                             Hudson, NY
# 7          S  NaN    NaN                            Belfast, NI
# 8          S    D    NaN                    Bayside, Queens, NY
# 9          C  NaN   22.0                    Montevideo, Uruguay
# 10         C  NaN  124.0                           New York, NY
# 11         C    4    NaN                           New York, NY
# 12         C    9    NaN                          Paris, France
# 13         S    6    NaN                                    NaN
# 14         S    B    NaN                          Hessle, Yorks
# 15         S  NaN    NaN                           New York, NY
# 16         C  NaN    NaN                           Montreal, PQ
# 17         C    6    NaN                           Montreal, PQ
# 18         C    8    NaN                                    NaN
# 19         C    A    NaN                           Winnipeg, MN
# 20         S    5    NaN                           New York, NY
# 21         S    5    NaN                           New York, NY
# 22         C    5    NaN                           New York, NY
# 23         C    4    NaN                                    NaN
# 24         S    8    NaN                                    NaN
# 25         C  NaN  148.0                      San Francisco, CA
# 26         C    7    NaN                           Dowagiac, MI
# 27         C    7    NaN                           Dowagiac, MI
# 28         S    8    NaN                                    NaN
# 29         S    D    NaN     Stockholm, Sweden / Washington, DC
# ..       ...  ...    ...                                    ...
# 470        Q  NaN    NaN                                    NaN
# 471        S    9    NaN                  London / New York, NY
# 472        Q  NaN    NaN                   Glasgow / Bangor, ME
# 473        S  NaN    NaN                                Belfast
# 474        S  NaN  165.0                 Sweden / Arlington, NJ
# 475        S  NaN    NaN                        Minneapolis, MN
# 476        S  NaN    NaN                        Minneapolis, MN
# 477        Q  NaN    NaN                                    NaN
# 478        C   14    NaN                          Paris / Haiti
# 479        C   14    NaN                          Paris / Haiti
# 480        C  NaN    NaN                          Paris / Haiti
# 481        C   14    NaN                          Paris / Haiti
# 482        C   12    NaN  Berne, Switzerland / Central City, IA
# 483        S   11    NaN                   London / Chicago, IL
# 484        S   14    NaN                            Chicago, IL
# 485        C  NaN    NaN                           Montreal, PQ
# 486        S  NaN  108.0                                    NaN
# 487        Q  NaN    NaN                                    NaN
# 488        S  NaN  121.0            Weston-Super-Mare, Somerset
# 489        S  NaN    NaN            Weston-Super-Mare, Somerset
# 490        S  NaN   52.0             Southampton / New York, NY
# 491        C  NaN    NaN                                  Paris
# 492        C   10    NaN                   Paris / Montreal, PQ
# 493        C  NaN    NaN                   Paris / Montreal, PQ
# 494        C   10    NaN                   Paris / Montreal, PQ
# 495        C  NaN    NaN                           New York, NY
# 496        S  NaN    NaN                   St Austall, Cornwall
# 497        S  NaN    NaN      Weston-Super-Mare / Moose Jaw, SK
# 498        S  NaN  209.0                      Sydney, Australia
# 499        S  NaN    NaN                             Sarnia, ON
#
# [500 rows x 14 columns]

# %%
pd.Categorical(titanic.pclass)
# Out:
# [1, 1, 1, 1, 1, ..., 3, 3, 3, 3, 3]
# Length: 1309
# Categories (3, int64): [1, 2, 3]

# %%
titanic['pclass']=titanic.pclass.astype('category')

# %%
titanic.pclass.describe()
# Out:
# count     1309
# unique       3
# top          3
# freq       709
# Name: pclass, dtype: int64

# %%
titanic.hist('age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113468c50>]], dtype=object)

# %%
titanic.fare.value_counts()
# Out:
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
# 10.5000    35
# 7.7750     26
# 7.2292     24
# 7.9250     23
# 26.5500    22
# 7.2250     21
# 7.8542     21
# 8.6625     21
# 7.2500     18
# 0.0000     17
# 21.0000    14
# 9.5000     12
# 16.1000    12
# 27.7208    11
# 69.5500    11
# 14.5000    11
# 15.5000    10
# 14.4542    10
# 7.8792     10
# 7.7958     10
# 15.2458     9
# 24.1500     9
# 7.0500      9
# 46.9000     8
# 56.4958     8
#            ..
# 7.7208      1
# 9.6875      1
# 49.5000     1
# 8.6833      1
# 9.2167      1
# 8.6542      1
# 7.5750      1
# 25.7000     1
# 31.6833     1
# 8.9625      1
# 10.5167     1
# 9.8458      1
# 9.8417      1
# 40.1250     1
# 7.5792      1
# 8.4333      1
# 38.5000     1
# 15.0333     1
# 4.0125      1
# 7.8500      1
# 12.7375     1
# 34.0208     1
# 6.4500      1
# 25.9250     1
# 7.0458      1
# 13.7917     1
# 10.7083     1
# 7.7417      1
# 7.8208      1
# 34.6542     1
# Name: fare, Length: 281, dtype: int64

# %%
titanic.pclass.value_counts().plot(kind='bar')

# %%
titanic.embarked.value_counts().plot(kind='bar')

# %%
titanic.fare.hist(bins=20)

# %%
titanic.sex.value_counts().plot(kind='bar')

# %%
titanic.age.hist(bins=10)

# %%
titanic.cabin = titanic.cabin.astype(str)
findarray = []
for x in titanic.cabin:
    if (x[0] in findarray) or x[0] == 'n':
        continue
    findarray.append(x[0])
findarray.sort()
findresult=[]
for j in findarray:
    num=[i.startswith(j) for i in titanic.cabin]
    findresult.append(np.sum(num))
findresult
# Out:
# [22, 65, 94, 46, 41, 21, 5, 1]

# %%
series = pd.Series(findresult, index = findarray, name = 'Proportion of passengers by cabin floor')
series.plot.pie(autopct = '%.1f',figsize = (6, 6))
